# %% [markdown]
# ### 1.Read data

# %%
# Out:
#                       Australian Bureau of Statistics  \
# 0   2033.0.55.001 Socio-Economic Indexes for Austr...
# 1   Released at 10.30am (Canberra time) 27 March 2018
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                            Contents
# 4                                              Tables
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                  6
# 11                                                  7
# 12                                  Explanatory Notes
# 13                                                NaN
# 14                                                NaN
# 15    More information available from the ABS website
# 16                                                NaN
# 17  Socio-Economic Indexes for Australia (SEIFA), ...
# 18                                            Summary
# 19                                 Explanatory Notes
# 20                                                NaN
# 21                                                NaN
# 22                                          Inquiries
# 23                                                NaN
# 24  Further information about these and related st...
# 25                                                NaN
# 26                                                NaN
# 27                   © Commonwealth of Australia 2018
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Statistical Area Level 1 (SA1) SEIFA Summary, ...
# 6   Statistical Area Level 1 (SA1) Index of Relati...
# 7   Statistical Area Level 1 (SA1) Index of Relati...
# 8   Statistical Area Level 1 (SA1) Index of Econom...
# 9   Statistical Area Level 1 (SA1) Index of Educat...
# 10  Statistical Area Level 1 (SA1) Excluded Areas,...
# 11                       Geographic Information, 2016
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN

# %%
import pandas as pd 
import numpy as np

SA1_file = "C:/Users/Cowboy/Documents/GitHub/GovHack2021/2033055001 - sa1 indexes.xls"
df_sa1 = pd.read_excel(SA1_file)

xls = pd.ExcelFile(SA1_file)
df = xls.parse('Table 1', skiprows=5, index_col=None, na_values=['NA'])
df = df.replace('-', np.nan)
columns1 = ["SA1_7code", "SA1_11code", 
           "Score_disadvantage", "Decile_disadvantage", 
           "Score_advantage", "Decile_advantage", 
           "Score_economic", "Decile_economic", 
           "Score_occupation", "Decile_occupation",
           "population"]
df.columns = columns1
df.drop(columns=["SA1_11code"], inplace=True)
df.drop(df.tail(2).index, inplace=True)
#df = df.set_index("SA1_7code")
df = df.fillna(df.mean())
df.head()
# Out:
#    SA1_7code  Score_disadvantage  Decile_disadvantage  Score_advantage  \
# 0    1100701               991.0                  4.0            972.0
# 1    1100702              1044.0                  7.0           1044.0
# 2    1100703               980.0                  4.0            962.0
# 3    1100704               984.0                  4.0            970.0
# 4    1100705               944.0                  3.0            936.0
#
#    Decile_advantage  Score_economic  Decile_economic  Score_occupation  \
# 0               4.0          1001.0              5.0             984.0
# 1               7.0          1078.0              8.0            1055.0
# 2               4.0           951.0              3.0            1010.0
# 3               4.0           986.0              5.0            1026.0
# 4               3.0           965.0              4.0             979.0
#
#    Decile_occupation  population
# 0                5.0       256.0
# 1                7.0       381.0
# 2                6.0       428.0
# 3                6.0       446.0
# 4                5.0       402.0

# %%
df["state"] = df["SA1_7code"].astype(str).str[0].astype(int)
df = df.loc[df['state'] == 2]
df = df.set_index("SA1_7code")
df.drop(columns="state",inplace=True)

# %%
df
# Out:
#            Score_disadvantage  Decile_disadvantage  Score_advantage  \
# SA1_7code
# 2100101                1001.0                  5.0            975.0
# 2100102                 955.0                  3.0            936.0
# 2100105                 925.0                  2.0            926.0
# 2100106                 999.0                  5.0            971.0
# 2100107                 909.0                  2.0            903.0
# ...                       ...                  ...              ...
# 2148031                1006.0                  5.0            998.0
# 2148032                1016.0                  5.0            999.0
# 2148033                1049.0                  7.0           1018.0
# 2148034                1010.0                  5.0            985.0
# 2148035                1027.0                  6.0            994.0
#
#            Decile_advantage  Score_economic  Decile_economic  \
# SA1_7code
# 2100101                 4.0           969.0              4.0
# 2100102                 3.0          1001.0              5.0
# 2100105                 3.0           876.0              2.0
# 2100106                 4.0           968.0              4.0
# 2100107                 2.0           874.0              1.0
# ...                     ...             ...              ...
# 2148031                 5.0          1034.0              7.0
# 2148032                 5.0           978.0              4.0
# 2148033                 6.0          1041.0              7.0
# 2148034                 5.0           953.0              3.0
# 2148035                 5.0           996.0              5.0
#
#            Score_occupation  Decile_occupation  population  KMeans
# SA1_7code
# 2100101               984.0                5.0       434.0       0
# 2100102               943.0                3.0       214.0       0
# 2100105               983.0                5.0       301.0       0
# 2100106               990.0                5.0       560.0       1
# 2100107               975.0                5.0       369.0       0
# ...                     ...                ...         ...     ...
# 2148031               995.0                5.0       287.0       2
# 2148032              1025.0                6.0       163.0       2
# 2148033              1003.0                6.0       621.0       1
# 2148034              1014.0                6.0       279.0       2
# 2148035               993.0                5.0       507.0       1
#
# [13652 rows x 10 columns]

# %%
print(len(df[df['Decile_occupation']==5.500009069307649]))
df.loc[df['Decile_occupation']==5.500009069307649, 'Decile_occupation'] = 5.5
print(len(df[df['Decile_occupation']==5.500009069307649]))
# Out:
# 0
# 0

# %%
df_norm = pd.get_dummies(df, columns=["Decile_disadvantage","Decile_advantage", "Decile_economic", "Decile_occupation"])
df_norm.head()
# Out:
#            Score_disadvantage  Score_advantage  Score_economic  \
# SA1_7code
# 2100101                1001.0            975.0           969.0
# 2100102                 955.0            936.0          1001.0
# 2100105                 925.0            926.0           876.0
# 2100106                 999.0            971.0           968.0
# 2100107                 909.0            903.0           874.0
#
#            Score_occupation  population  KMeans  Decile_disadvantage_1.0  \
# SA1_7code
# 2100101               984.0       434.0       0                        0
# 2100102               943.0       214.0       0                        0
# 2100105               983.0       301.0       0                        0
# 2100106               990.0       560.0       1                        0
# 2100107               975.0       369.0       0                        0
#
#            Decile_disadvantage_2.0  Decile_disadvantage_3.0  \
# SA1_7code
# 2100101                          0                        0
# 2100102                          0                        1
# 2100105                          1                        0
# 2100106                          0                        0
# 2100107                          1                        0
#
#            Decile_disadvantage_4.0  ...  Decile_occupation_2.0  \
# SA1_7code                           ...
# 2100101                          0  ...                      0
# 2100102                          0  ...                      0
# 2100105                          0  ...                      0
# 2100106                          0  ...                      0
# 2100107                          0  ...                      0
#
#            Decile_occupation_3.0  Decile_occupation_4.0  \
# SA1_7code
# 2100101                        0                      0
# 2100102                        1                      0
# 2100105                        0                      0
# 2100106                        0                      0
# 2100107                        0                      0
#
#            Decile_occupation_5.0  Decile_occupation_5.5  \
# SA1_7code
# 2100101                        1                      0
# 2100102                        0                      0
# 2100105                        1                      0
# 2100106                        1                      0
# 2100107                        1                      0
#
#            Decile_occupation_6.0  Decile_occupation_7.0  \
# SA1_7code
# 2100101                        0                      0
# 2100102                        0                      0
# 2100105                        0                      0
# 2100106                        0                      0
# 2100107                        0                      0
#
#            Decile_occupation_8.0  Decile_occupation_9.0  \
# SA1_7code
# 2100101                        0                      0
# 2100102                        0                      0
# 2100105                        0                      0
# 2100106                        0                      0
# 2100107                        0                      0
#
#            Decile_occupation_10.0
# SA1_7code
# 2100101                         0
# 2100102                         0
# 2100105                         0
# 2100106                         0
# 2100107                         0
#
# [5 rows x 50 columns]

# %% [markdown]
# ### 2.Kmeans

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib inline
from sklearn import datasets

# %%
km = KMeans(n_clusters=4)
km.fit(df_norm)
km.predict(df_norm)
labels = km.labels_

# %%
df['KMeans'] = labels.tolist()
df.head()
# Out:
#            Score_disadvantage  Decile_disadvantage  Score_advantage  \
# SA1_7code
# 2100101                1001.0                  5.0            975.0
# 2100102                 955.0                  3.0            936.0
# 2100105                 925.0                  2.0            926.0
# 2100106                 999.0                  5.0            971.0
# 2100107                 909.0                  2.0            903.0
#
#            Decile_advantage  Score_economic  Decile_economic  \
# SA1_7code
# 2100101                 4.0           969.0              4.0
# 2100102                 3.0          1001.0              5.0
# 2100105                 3.0           876.0              2.0
# 2100106                 4.0           968.0              4.0
# 2100107                 2.0           874.0              1.0
#
#            Score_occupation  Decile_occupation  population  KMeans
# SA1_7code
# 2100101               984.0                5.0       434.0       2
# 2100102               943.0                3.0       214.0       2
# 2100105               983.0                5.0       301.0       2
# 2100106               990.0                5.0       560.0       1
# 2100107               975.0                5.0       369.0       2

# %% [markdown]
# #### test KMean if need to predict on the fly

# %%
import pickle 

with open("./models/Kmeans.pkl", "wb") as f:
    pickle.dump(km, f)
    
with open("./models/Kmeans_Columns.pkl", "wb") as f:
    pickle.dump(list(df_norm.columns), f)

# %%
with open("./models/Kmeans.pkl", "rb") as f:
    model = pickle.load(f)
    
with open("./models/Kmeans_Columns.pkl", "rb") as f: 
    columns_lst = pickle.load(f)

# %%
# test
df_test = df[df.index.isin([2100101, 2100102])]
df_test_norm = pd.get_dummies(df_test, columns=["Decile_disadvantage","Decile_advantage", "Decile_economic", "Decile_occupation"])
df_test_norm = df_test_norm.reindex(columns=columns_lst, fill_value=0)

# %%
model.predict(df_test_norm)
# Out:
# array([2, 2])

# %%
df[df.index.isin([2100101, 2100102])]["KMeans"]
# Out:
# SA1_7code
# 2100101    2
# 2100102    2
# Name: KMeans, dtype: int64

# %% [markdown]
# ### 3.K-prototypes

# %%
from kmodes.kprototypes import KPrototypes

kproto = KPrototypes(n_clusters=4, init='Cao')
clusters = kproto.fit_predict(df, categorical=[1, 3, 5, 7])

df['kprototypes'] = clusters.tolist()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-128-114b3c3ee90c> in <module>
# ----> 1 from kmodes.kprototypes import KPrototypes
#       2
#       3 kproto = KPrototypes(n_clusters=4, init='Cao')
#       4 clusters = kproto.fit_predict(df, categorical=[1, 3, 5, 7])
#       5
#
# ModuleNotFoundError: No module named 'kmodes'

# %% [markdown]
# ### 4.Export result to csv

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.to_csv("SocioEconomic_Clusting_result.csv")
